# %%
import tensorflow as tf
from model import Model
from input_pipe import InputPipe
from feeder import VarFeeder
from tqdm import trange
import matplotlib.pyplot as plt
import collections
import pandas as pd
import numpy as np
from trainer import predict
from hparams import build_hparams
import hparams
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
def smape(true, pred):
    summ = np.abs(true) + np.abs(pred)
    smape = np.where(summ == 0, 0, np.abs(true - pred) / summ)
    #return np.mean(kaggle_smape) * 200
    return smape * 200

def mean_smape(true, pred):
    raw_smape = smape(true, pred)
    masked_smape = np.ma.array(raw_smape, mask=np.isnan(raw_smape))
    return masked_smape.mean()

# %%
from make_features import read_all
df_all = read_all()
df_all.columns
# Out:
# DatetimeIndex(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#                '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08',
#                '2015-07-09', '2015-07-10',
#                ...
#                '2017-09-02', '2017-09-03', '2017-09-04', '2017-09-05',
#                '2017-09-06', '2017-09-07', '2017-09-08', '2017-09-09',
#                '2017-09-10', '2017-09-11'],
#               dtype='datetime64[ns]', length=804, freq=None)

# %%
prev = df_all#.loc[:,:'2017-07-08']

# %%
paths = [p for p in tf.train.get_checkpoint_state('data/cpt/s32').all_model_checkpoint_paths]

# %%
#tf.reset_default_graph()
#preds = predict(paths, default_hparams(), back_offset=0,
#                    n_models=3, target_model=0, seed=2, batch_size=2048, asgd=True)
t_preds = []
for tm in range(3):
    tf.reset_default_graph()
    t_preds.append(predict(paths, build_hparams(hparams.params_s32), back_offset=0, predict_window=63,
                    n_models=3, target_model=tm, seed=2, batch_size=2048, asgd=True))
# Out:
# WARNING:tensorflow:From /home/artur/work/kaggle/web-traffic-light/model.py:177: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Restoring parameters from data/vars/feeder.cpt
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-10944
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11001
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11058
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11115
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11172
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11229
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11286
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11343
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11400
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11457
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/vars/feeder.cpt
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-10944
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11001
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11058
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11115
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11172
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11229
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11286
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11343
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11400
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11457
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/vars/feeder.cpt
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-10944
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11001
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11058
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11115
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11172
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11229
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11286
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11343
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11400
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11457
# 0......................................................................🎉

# %%
preds=sum(t_preds) /3

# %%
missing_pages = prev.index.difference(preds.index)
# Use zeros for missing pages
rmdf = pd.DataFrame(index=missing_pages,
                    data=np.tile(0, (len(preds.columns),len(missing_pages))).T, columns=preds.columns)
f_preds = preds.append(rmdf).sort_index()

# Use zero for negative predictions
f_preds[f_preds < 0.5] = 0
# Rouns predictions to nearest int
f_preds = np.round(f_preds).astype(np.int64)

# %% [markdown]
# Visual sanity check

# %%
#page = '(236984)_Astier_fr.wikipedia.org_all-access_all-agents'
#page = '龍抬頭_zh.wikipedia.org_mobile-web_all-agents'
#page = "'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-John_album)_en.wikipedia.org_mobile-web_all-agents"
#page='Peter_Townsend_(RAF_officer)_en.wikipedia.org_mobile-web_all-agents'
page="Heahmund_en.wikipedia.org_desktop_all-agents"
prev.loc[page].fillna(0).plot(logy=True)

#gt.loc[page].fillna(0).plot(logy=True)
f_preds.loc[page].plot(logy=True)

# %%
def read_keys():
    import os.path
    key_file = 'data/keys2.pkl'
    if os.path.exists(key_file):
        return pd.read_pickle(key_file)
    else:
        print('Reading keys...')
        raw_keys = pd.read_csv('data/key_2.csv.zip')
        print('Processing keys...')
        pagedate = raw_keys.Page.str.rsplit('_', expand=True, n=1).rename(columns={0:'page',1:'date_str'})
        keys = raw_keys.drop('Page', axis=1).assign(page=pagedate.page, date=pd.to_datetime(pagedate.date_str))
        del raw_keys, pagedate
        print('Pivoting keys...')
        pkeys = keys.pivot(index='page', columns='date', values='Id')
        print('Storing keys...')
        pkeys.to_pickle(key_file)
        return pkeys
keys = read_keys()

# %%
subm_preds = f_preds.loc[:, '2017-09-13':]
assert np.all(subm_preds.index == keys.index)
assert np.all(subm_preds.columns == keys.columns)
answers = pd.DataFrame({'Id':keys.values.flatten(), 'Visits':np.round(subm_preds).astype(np.int64).values.flatten()})
answers.to_csv('data/submission.csv.gz', compression='gzip', index=False, header=True)

# %%
f_preds
# Out:
#                                                     2017-09-12  2017-09-13  \
# !vote_en.wikipedia.org_all-access_all-agents                10          10
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           5
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1059        1079
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          20          19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         623         627
# "European_Society_for_Clinical_Investigation"_e...           1           1
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           1           1
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         619         619
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         425         425
# "Keep_me_logged_in"_extended_to_one_year_www.me...          30          29
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          19          18
# "Keep_me_logged_in"_extended_to_one_year_www.me...          11          11
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2574        2608
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          56          58
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1312        1334
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           5           5
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          49          48
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           4           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          21          20
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          28          29
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              217         194
# (236984)_Astier_fr.wikipedia.org_all-access_all...          18          18
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       8           8
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     37          37
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  29          29
# 龍應台_zh.wikipedia.org_all-access_all-agents                 395         387
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    247         238
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 101         102
# 龍涎香_zh.wikipedia.org_all-access_spider                       8           8
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     54          56
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 955         947
# 龍珠超_zh.wikipedia.org_all-access_spider                      26          27
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    647         634
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 305         305
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                414         423
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   255         265
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 247         245
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    113         111
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 127         126
# 龔照勝_zh.wikipedia.org_desktop_all-agents                     11          11
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                207         208
# 대문_commons.wikimedia.org_all-access_all-agents             193         184
# 대문_commons.wikimedia.org_all-access_spider                  19          20
# 대문_commons.wikimedia.org_desktop_all-agents                194         182
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1120        1140
# ［Alexandros］_ja.wikipedia.org_all-access_spider             78          80
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           311         314
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         817         827
#
#                                                     2017-09-14  2017-09-15  \
# !vote_en.wikipedia.org_all-access_all-agents                 9           9
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1058        1045
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          19          18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         611         592
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         614         603
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         421         402
# "Keep_me_logged_in"_extended_to_one_year_www.me...          28          28
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          18          18
# "Keep_me_logged_in"_extended_to_one_year_www.me...          12          12
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2636        2648
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          58          57
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1333        1271
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           5           5
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          48          47
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          20          18
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          28          28
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              178         162
# (236984)_Astier_fr.wikipedia.org_all-access_all...          17          17
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       9           9
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     37          36
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  29          33
# 龍應台_zh.wikipedia.org_all-access_all-agents                 371         346
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    224         201
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   5           5
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 101          99
# 龍涎香_zh.wikipedia.org_all-access_spider                       8           8
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     55          52
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 922         942
# 龍珠超_zh.wikipedia.org_all-access_spider                      27          27
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    617         626
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 301         313
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                423         399
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   264         237
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 242         236
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    109         105
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 123         121
# 龔照勝_zh.wikipedia.org_desktop_all-agents                     10           9
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                209         213
# 대문_commons.wikimedia.org_all-access_all-agents             179         170
# 대문_commons.wikimedia.org_all-access_spider                  20          20
# 대문_commons.wikimedia.org_desktop_all-agents                175         164
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1149        1185
# ［Alexandros］_ja.wikipedia.org_all-access_spider             82          84
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           313         312
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         837         871
#
#                                                     2017-09-16  2017-09-17  \
# !vote_en.wikipedia.org_all-access_all-agents                 9           8
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1053        1079
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          19          19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         572         595
# "European_Society_for_Clinical_Investigation"_e...           3           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         598         622
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         373         392
# "Keep_me_logged_in"_extended_to_one_year_www.me...          27          26
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           2
# "Keep_me_logged_in"_extended_to_one_year_www.me...          17          16
# "Keep_me_logged_in"_extended_to_one_year_www.me...          13          13
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2638        2748
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          54          54
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1085        1096
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           5           5
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          44          45
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           4
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          14          15
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          28          30
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              140         155
# (236984)_Astier_fr.wikipedia.org_all-access_all...          18          19
# (236984)_Astier_fr.wikipedia.org_all-access_spider           4           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      10           9
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     36          37
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  48          52
# 龍應台_zh.wikipedia.org_all-access_all-agents                 320         375
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    164         200
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 100         105
# 龍涎香_zh.wikipedia.org_all-access_spider                       9           9
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     47          49
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1187        1467
# 龍珠超_zh.wikipedia.org_all-access_spider                      31          33
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    778         987
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 392         450
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                345         364
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     16          17
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   173         181
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 230         244
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                     98         103
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 124         134
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                234         244
# 대문_commons.wikimedia.org_all-access_all-agents             152         159
# 대문_commons.wikimedia.org_all-access_spider                  20          20
# 대문_commons.wikimedia.org_desktop_all-agents                142         149
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1332        1402
# ［Alexandros］_ja.wikipedia.org_all-access_spider             95         101
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           318         332
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1027        1066
#
#                                                     2017-09-18  2017-09-19  \
# !vote_en.wikipedia.org_all-access_all-agents                 9           9
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           5
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1076        1074
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          19          19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         619         621
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         633         624
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         430         430
# "Keep_me_logged_in"_extended_to_one_year_www.me...          26          25
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          17          17
# "Keep_me_logged_in"_extended_to_one_year_www.me...          12          11
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2729        2685
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          59          60
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1347        1386
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          51          52
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          21          23
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          30          30
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              179         178
# (236984)_Astier_fr.wikipedia.org_all-access_all...          19          18
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      10          10
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     40          40
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  37          35
# 龍應台_zh.wikipedia.org_all-access_all-agents                 378         373
# 龍應台_zh.wikipedia.org_all-access_spider                      17          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    229         222
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 106         106
# 龍涎香_zh.wikipedia.org_all-access_spider                       9           9
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     56          57
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1170        1040
# 龍珠超_zh.wikipedia.org_all-access_spider                      30          29
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    807         697
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 359         330
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                438         450
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   262         272
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 245         238
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      15          15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    111         108
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 126         123
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      9           9
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                221         215
# 대문_commons.wikimedia.org_all-access_all-agents             180         182
# 대문_commons.wikimedia.org_all-access_spider                  21          21
# 대문_commons.wikimedia.org_desktop_all-agents                173         175
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1251        1237
# ［Alexandros］_ja.wikipedia.org_all-access_spider             89          88
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           334         333
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         906         900
#
#                                                     2017-09-20  2017-09-21  \
# !vote_en.wikipedia.org_all-access_all-agents                 9           8
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1071        1066
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          18          18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         620         615
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         626         616
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         432         422
# "Keep_me_logged_in"_extended_to_one_year_www.me...          25          25
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          16          16
# "Keep_me_logged_in"_extended_to_one_year_www.me...          11          11
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2677        2674
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          60          59
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1380        1363
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          54          54
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          23          22
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          30          32
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              172         165
# (236984)_Astier_fr.wikipedia.org_all-access_all...          18          18
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      10          10
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     38          36
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  34          33
# 龍應台_zh.wikipedia.org_all-access_all-agents                 377         365
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    225         217
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 108         105
# 龍涎香_zh.wikipedia.org_all-access_spider                       9           9
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     58          57
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 979         928
# 龍珠超_zh.wikipedia.org_all-access_spider                      29          28
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    649         612
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 316         304
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                453         447
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   275         271
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 238         234
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      15          15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    107         106
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 121         119
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      9           9
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                214         214
# 대문_commons.wikimedia.org_all-access_all-agents             182         177
# 대문_commons.wikimedia.org_all-access_spider                  21          21
# 대문_commons.wikimedia.org_desktop_all-agents                175         170
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1226        1226
# ［Alexandros］_ja.wikipedia.org_all-access_spider             88          88
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           331         330
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         893         891
#
#                                                        ...      2017-11-04  \
# !vote_en.wikipedia.org_all-access_all-agents           ...               7
# !vote_en.wikipedia.org_all-access_spider               ...               2
# !vote_en.wikipedia.org_desktop_all-agents              ...               4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...     ...            1110
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...     ...              18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...     ...             595
# "European_Society_for_Clinical_Investigation"_e...     ...               3
# "European_Society_for_Clinical_Investigation"_e...     ...               0
# "European_Society_for_Clinical_Investigation"_e...     ...               2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...     ...             624
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...     ...              14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...     ...             389
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...              22
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...               2
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...              15
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...               7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...     ...            2648
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...     ...              59
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...     ...            1047
# %s_www.mediawiki.org_mobile-web_all-agents             ...               0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...     ...              12
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...     ...               3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...     ...               6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...     ...             106
# 'Tis_the_Season_en.wikipedia.org_all-access_spider     ...               6
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...     ...              37
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...     ...              70
# (1)_Ceres_de.wikipedia.org_desktop_all-agents          ...             120
# (236984)_Astier_fr.wikipedia.org_all-access_all...     ...              21
# (236984)_Astier_fr.wikipedia.org_all-access_spider     ...               4
# ...                                                    ...             ...
# 龍千玉_zh.wikipedia.org_all-access_spider                 ...              14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                ...              33
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents             ...              80
# 龍應台_zh.wikipedia.org_all-access_all-agents             ...             276
# 龍應台_zh.wikipedia.org_all-access_spider                 ...              17
# 龍應台_zh.wikipedia.org_desktop_all-agents                ...             144
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents             ...               8
# 龍涎香_zh.wikipedia.org_all-access_all-agents             ...             111
# 龍涎香_zh.wikipedia.org_all-access_spider                 ...              10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                ...              52
# 龍珠超_zh.wikipedia.org_all-access_all-agents             ...            1111
# 龍珠超_zh.wikipedia.org_all-access_spider                 ...              33
# 龍珠超_zh.wikipedia.org_desktop_all-agents                ...             724
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents             ...             370
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents            ...             378
# 龐茲騙局_zh.wikipedia.org_all-access_spider                ...              17
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents               ...             179
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents             ...             255
# 龔嘉欣_zh.wikipedia.org_all-access_spider                 ...              15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                ...             102
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents             ...             152
# 龔照勝_zh.wikipedia.org_desktop_all-agents                ...               7
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents            ...             286
# 대문_commons.wikimedia.org_all-access_all-agents         ...             153
# 대문_commons.wikimedia.org_all-access_spider             ...              24
# 대문_commons.wikimedia.org_desktop_all-agents            ...             136
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...     ...            1702
# ［Alexandros］_ja.wikipedia.org_all-access_spider        ...             119
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents       ...             378
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...     ...            1322
#
#                                                     2017-11-05  2017-11-06  \
# !vote_en.wikipedia.org_all-access_all-agents                 6           6
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    3           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1126        1133
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          17          17
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         606         637
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           1           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         638         638
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         407         436
# "Keep_me_logged_in"_extended_to_one_year_www.me...          22          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           2           2
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2760        2675
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          57          60
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1070        1278
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          12          13
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         106         129
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           6
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          41          63
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          72          72
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              135         165
# (236984)_Astier_fr.wikipedia.org_all-access_all...          21          21
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     33          34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  89          62
# 龍應台_zh.wikipedia.org_all-access_all-agents                 298         314
# 龍應台_zh.wikipedia.org_all-access_spider                      17          17
# 龍應台_zh.wikipedia.org_desktop_all-agents                    160         188
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   8           8
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 110         108
# 龍涎香_zh.wikipedia.org_all-access_spider                      10          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     51          58
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1410        1092
# 龍珠超_zh.wikipedia.org_all-access_spider                      34          32
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    939         741
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 426         331
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                407         476
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     17          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   196         277
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 266         256
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      15          15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    105         112
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 161         142
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      7           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                300         267
# 대문_commons.wikimedia.org_all-access_all-agents             158         179
# 대문_commons.wikimedia.org_all-access_spider                  24          25
# 대문_commons.wikimedia.org_desktop_all-agents                142         167
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1699        1506
# ［Alexandros］_ja.wikipedia.org_all-access_spider            123         107
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           384         382
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1294        1094
#
#                                                     2017-11-07  2017-11-08  \
# !vote_en.wikipedia.org_all-access_all-agents                 7           7
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1131        1126
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          17          17
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         639         636
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         632         631
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         437         434
# "Keep_me_logged_in"_extended_to_one_year_www.me...          22          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           2           2
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2572        2552
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          61          61
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1290        1281
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          13          13
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         143         145
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           6           6
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          77          78
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          74          75
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              163         157
# (236984)_Astier_fr.wikipedia.org_all-access_all...          20          20
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     34          34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  55          54
# 龍應台_zh.wikipedia.org_all-access_all-agents                 311         312
# 龍應台_zh.wikipedia.org_all-access_spider                      17          17
# 龍應台_zh.wikipedia.org_desktop_all-agents                    187         186
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 109         108
# 龍涎香_zh.wikipedia.org_all-access_spider                      10          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     59          58
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 965         917
# 龍珠超_zh.wikipedia.org_all-access_spider                      31          31
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    638         602
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 308         297
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                480         483
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   282         285
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 249         246
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      15          15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    109         108
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 138         137
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                256         256
# 대문_commons.wikimedia.org_all-access_all-agents             184         184
# 대문_commons.wikimedia.org_all-access_spider                  25          25
# 대문_commons.wikimedia.org_desktop_all-agents                173         171
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1452        1445
# ［Alexandros］_ja.wikipedia.org_all-access_spider            105         103
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           379         377
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1048        1048
#
#                                                     2017-11-09  2017-11-10  \
# !vote_en.wikipedia.org_all-access_all-agents                 6           6
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1118        1111
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          17          17
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         630         619
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         599         595
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         405         397
# "Keep_me_logged_in"_extended_to_one_year_www.me...          21          21
# "Keep_me_logged_in"_extended_to_one_year_www.me...           2           2
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           6           6
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2519        2569
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          61          60
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1249        1203
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          12          12
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         131         128
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          70          63
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          67          68
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              152         143
# (236984)_Astier_fr.wikipedia.org_all-access_all...          20          20
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     33          33
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  54          58
# 龍應台_zh.wikipedia.org_all-access_all-agents                 305         294
# 龍應台_zh.wikipedia.org_all-access_spider                      17          17
# 龍應台_zh.wikipedia.org_desktop_all-agents                    181         169
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 108         106
# 龍涎香_zh.wikipedia.org_all-access_spider                      10          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     58          55
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 875         883
# 龍珠超_zh.wikipedia.org_all-access_spider                      30          30
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    573         580
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 288         294
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                468         426
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   274         241
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 242         239
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          15
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    106         102
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 135         135
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                254         259
# 대문_commons.wikimedia.org_all-access_all-agents             178         168
# 대문_commons.wikimedia.org_all-access_spider                  25          24
# 대문_commons.wikimedia.org_desktop_all-agents                165         154
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1454        1527
# ［Alexandros］_ja.wikipedia.org_all-access_spider            102         105
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           376         379
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1058        1133
#
#                                                     2017-11-11  2017-11-12  \
# !vote_en.wikipedia.org_all-access_all-agents                 7           6
# !vote_en.wikipedia.org_all-access_spider                     3           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           3
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1115        1128
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          18          17
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         598         608
# "European_Society_for_Clinical_Investigation"_e...           3           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         599         630
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         368         391
# "Keep_me_logged_in"_extended_to_one_year_www.me...          21          21
# "Keep_me_logged_in"_extended_to_one_year_www.me...           2           2
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          14
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2678        2768
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          59          58
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1048        1070
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          13          12
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           7           7
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         115         124
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           6           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          43          47
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          72          83
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              123         139
# (236984)_Astier_fr.wikipedia.org_all-access_all...          21          22
# (236984)_Astier_fr.wikipedia.org_all-access_spider           4           4
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          15
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     33          34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  86          96
# 龍應台_zh.wikipedia.org_all-access_all-agents                 282         303
# 龍應台_zh.wikipedia.org_all-access_spider                      17          17
# 龍應台_zh.wikipedia.org_desktop_all-agents                    147         159
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 106         110
# 龍涎香_zh.wikipedia.org_all-access_spider                      11          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     49          52
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1109        1396
# 龍珠超_zh.wikipedia.org_all-access_spider                      33          34
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    729         935
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 364         420
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                369         403
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     17          17
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   180         204
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 246         253
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                     98         100
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 150         155
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      7           7
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                290         306
# 대문_commons.wikimedia.org_all-access_all-agents             151         157
# 대문_commons.wikimedia.org_all-access_spider                  24          24
# 대문_commons.wikimedia.org_desktop_all-agents                133         140
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1711        1743
# ［Alexandros］_ja.wikipedia.org_all-access_spider            119         123
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           382         391
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1317        1330
#
#                                                     2017-11-13
# !vote_en.wikipedia.org_all-access_all-agents                 6
# !vote_en.wikipedia.org_all-access_spider                     2
# !vote_en.wikipedia.org_desktop_all-agents                    4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1136
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          17
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         638
# "European_Society_for_Clinical_Investigation"_e...           2
# "European_Society_for_Clinical_Investigation"_e...           0
# "European_Society_for_Clinical_Investigation"_e...           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         628
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         423
# "Keep_me_logged_in"_extended_to_one_year_www.me...          21
# "Keep_me_logged_in"_extended_to_one_year_www.me...           2
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2614
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          61
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1250
# %s_www.mediawiki.org_mobile-web_all-agents                   0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          14
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           7
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         157
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          77
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          87
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              164
# (236984)_Astier_fr.wikipedia.org_all-access_all...          22
# (236984)_Astier_fr.wikipedia.org_all-access_spider           4
# ...                                                        ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      15
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  62
# 龍應台_zh.wikipedia.org_all-access_all-agents                 306
# 龍應台_zh.wikipedia.org_all-access_spider                      18
# 龍應台_zh.wikipedia.org_desktop_all-agents                    181
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   8
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 113
# 龍涎香_zh.wikipedia.org_all-access_spider                      10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     61
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1090
# 龍珠超_zh.wikipedia.org_all-access_spider                      33
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    741
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 329
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                461
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   279
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 248
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    107
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 139
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                273
# 대문_commons.wikimedia.org_all-access_all-agents             178
# 대문_commons.wikimedia.org_all-access_spider                  25
# 대문_commons.wikimedia.org_desktop_all-agents                165
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1537
# ［Alexandros］_ja.wikipedia.org_all-access_spider            108
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           386
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1115
#
# [145063 rows x 63 columns]

# %%
prev.loc[missing_pages, '2016-12-15':]
# Out:
#                                                     2016-12-15  2016-12-16  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         1.0         NaN
# Category:Deletion_requests_January_2016_commons...         0.0         NaN
# Category:Deletion_requests_January_2016_commons...         1.0         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-17  2016-12-18  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         0.0
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         0.0         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-19  2016-12-20  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         0.0
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         0.0         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         1.0
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             0.0         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-21  2016-12-22  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         0.0         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-23  2016-12-24  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         0.0         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         4.0         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         0.0
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                        ...      2017-09-02  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...     ...             NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...     ...             NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...     ...             NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...     ...             NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider       ...             NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents      ...             NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...     ...             NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...     ...             NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...     ...             NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...     ...             NaN
# Artificial_Insemination's_Art_www.mediawiki.org...     ...             NaN
# Artificial_Insemination's_Art_www.mediawiki.org...     ...             NaN
# Category:Deletion_requests_April_2016_commons.w...     ...             NaN
# Category:Deletion_requests_April_2016_commons.w...     ...             NaN
# Category:Deletion_requests_April_2016_commons.w...     ...             NaN
# Category:Deletion_requests_February_2016_common...     ...             NaN
# Category:Deletion_requests_February_2016_common...     ...             NaN
# Category:Deletion_requests_February_2016_common...     ...             NaN
# Category:Deletion_requests_January_2016_commons...     ...             NaN
# Category:Deletion_requests_January_2016_commons...     ...             NaN
# Category:Deletion_requests_January_2016_commons...     ...             NaN
# Category:Deletion_requests_July_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_June_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_June_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_June_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_March_2016_commons.w...     ...             NaN
# Category:Deletion_requests_May_2016_commons.wik...     ...             NaN
# Category:Deletion_requests_May_2016_commons.wik...     ...             NaN
# Category:Deletion_requests_May_2016_commons.wik...     ...             NaN
# Category:Deletion_requests_October_2016_commons...     ...             NaN
# ...                                                    ...             ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...     ...             NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...     ...             NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents             ...             NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                 ...             NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                ...             NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents             ...             NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents         ...             NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider            ...             NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents        ...             0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents             ...             NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                 ...             NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents             ...             NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents         ...             NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents           ...             NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider               ...             NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents              ...             NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents             ...             NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                 ...             NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                ...             NaN
#
#                                                     2017-09-03  2017-09-04  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-05  2017-09-06  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         2.0         1.0
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         0.0
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-07  2017-09-08  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         0.0         0.0
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             0.0         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            0.0         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 0.0         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             0.0         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-09  2017-09-10  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-11
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN
# Category:Deletion_requests_February_2016_common...         NaN
# Category:Deletion_requests_February_2016_common...         NaN
# Category:Deletion_requests_February_2016_common...         NaN
# Category:Deletion_requests_January_2016_commons...         NaN
# Category:Deletion_requests_January_2016_commons...         NaN
# Category:Deletion_requests_January_2016_commons...         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN
# Category:Deletion_requests_October_2016_commons...         NaN
# ...                                                        ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN
#
# [798 rows x 271 columns]
