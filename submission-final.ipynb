# %%
import tensorflow as tf
from model import Model
from input_pipe import InputPipe
from feeder import VarFeeder
from tqdm import trange
import matplotlib.pyplot as plt
import collections
import pandas as pd
import numpy as np
from trainer import predict
from hparams import build_hparams
import hparams
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
def smape(true, pred):
    summ = np.abs(true) + np.abs(pred)
    smape = np.where(summ == 0, 0, np.abs(true - pred) / summ)
    #return np.mean(kaggle_smape) * 200
    return smape * 200

def mean_smape(true, pred):
    raw_smape = smape(true, pred)
    masked_smape = np.ma.array(raw_smape, mask=np.isnan(raw_smape))
    return masked_smape.mean()

# %%
from make_features import read_all
df_all = read_all()
df_all.columns
# Out:
# DatetimeIndex(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#                '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08',
#                '2015-07-09', '2015-07-10',
#                ...
#                '2017-09-02', '2017-09-03', '2017-09-04', '2017-09-05',
#                '2017-09-06', '2017-09-07', '2017-09-08', '2017-09-09',
#                '2017-09-10', '2017-09-11'],
#               dtype='datetime64[ns]', length=804, freq=None)

# %%
prev = df_all#.loc[:,:'2017-07-08']

# %%
paths = [p for p in tf.train.get_checkpoint_state('data/cpt/s32').all_model_checkpoint_paths]

# %%
#tf.reset_default_graph()
#preds = predict(paths, default_hparams(), back_offset=0,
#                    n_models=3, target_model=0, seed=2, batch_size=2048, asgd=True)
t_preds = []
for tm in range(3):
    tf.reset_default_graph()
    t_preds.append(predict(paths, build_hparams(hparams.params_s32), back_offset=0, predict_window=63,
                    n_models=3, target_model=tm, seed=2, batch_size=2048, asgd=True))
# Out:
# INFO:tensorflow:Restoring parameters from data/vars/feeder.cpt
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-10944
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11001
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11058
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11115
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11172
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11229
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11286
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11343
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11400
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11457
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/vars/feeder.cpt
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-10944
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11001
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11058
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11115
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11172
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11229
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11286
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11343
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11400
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11457
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/vars/feeder.cpt
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-10944
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11001
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11058
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11115
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11172
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11229
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11286
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11343
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11400
# 0......................................................................🎉
# INFO:tensorflow:Restoring parameters from data/cpt/s32/cpt-11457
# 0......................................................................🎉

# %%
preds=sum(t_preds) /3

# %%
missing_pages = prev.index.difference(preds.index)
# Use zeros for missing pages
rmdf = pd.DataFrame(index=missing_pages,
                    data=np.tile(0, (len(preds.columns),len(missing_pages))).T, columns=preds.columns)
f_preds = preds.append(rmdf).sort_index()

# Use zero for negative predictions
f_preds[f_preds < 0.5] = 0
# Rouns predictions to nearest int
f_preds = np.round(f_preds).astype(np.int64)

# %% [markdown]
# Visual sanity check

# %%
page = '(236984)_Astier_fr.wikipedia.org_all-access_all-agents'
#page = '龍抬頭_zh.wikipedia.org_mobile-web_all-agents'
#page = "'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-John_album)_en.wikipedia.org_mobile-web_all-agents"
#page='Peter_Townsend_(RAF_officer)_en.wikipedia.org_mobile-web_all-agents'
#page="Heahmund_en.wikipedia.org_desktop_all-agents"
prev.loc[page].fillna(0).plot(logy=True)

#gt.loc[page].fillna(0).plot(logy=True)
f_preds.loc[page].plot(logy=True)

# %%
def read_keys():
    import os.path
    key_file = 'data/keys2.pkl'
    if os.path.exists(key_file):
        return pd.read_pickle(key_file)
    else:
        print('Reading keys...')
        raw_keys = pd.read_csv('data/key_2.csv.zip')
        print('Processing keys...')
        pagedate = raw_keys.Page.str.rsplit('_', expand=True, n=1).rename(columns={0:'page',1:'date_str'})
        keys = raw_keys.drop('Page', axis=1).assign(page=pagedate.page, date=pd.to_datetime(pagedate.date_str))
        del raw_keys, pagedate
        print('Pivoting keys...')
        pkeys = keys.pivot(index='page', columns='date', values='Id')
        print('Storing keys...')
        pkeys.to_pickle(key_file)
        return pkeys
keys = read_keys()

# %%
subm_preds = f_preds.loc[:, '2017-09-13':]
assert np.all(subm_preds.index == keys.index)
assert np.all(subm_preds.columns == keys.columns)
answers = pd.DataFrame({'Id':keys.values.flatten(), 'Visits':np.round(subm_preds).astype(np.int64).values.flatten()})
answers.to_csv('data/submission.csv.gz', compression='gzip', index=False, header=True)

# %%
f_preds
# Out:
#                                                     2017-09-12  2017-09-13  \
# !vote_en.wikipedia.org_all-access_all-agents                11          11
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    6           5
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1081        1089
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          21          21
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         641         645
# "European_Society_for_Clinical_Investigation"_e...           1           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           1           1
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         613         611
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         421         420
# "Keep_me_logged_in"_extended_to_one_year_www.me...          29          28
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          19          19
# "Keep_me_logged_in"_extended_to_one_year_www.me...           9          10
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2570        2582
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          59          59
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1293        1308
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           4           5
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          48          47
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           4           4
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          20          20
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          27          27
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              221         199
# (236984)_Astier_fr.wikipedia.org_all-access_all...          17          17
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       7           8
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     33          35
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  27          28
# 龍應台_zh.wikipedia.org_all-access_all-agents                 403         390
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    247         235
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   5           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 103         102
# 龍涎香_zh.wikipedia.org_all-access_spider                       8           8
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     55          55
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 975         915
# 龍珠超_zh.wikipedia.org_all-access_spider                      27          27
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    660         616
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 316         299
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                420         428
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   263         269
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 252         254
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      17          17
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    112         113
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 131         130
# 龔照勝_zh.wikipedia.org_desktop_all-agents                     11          11
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                207         207
# 대문_commons.wikimedia.org_all-access_all-agents             196         189
# 대문_commons.wikimedia.org_all-access_spider                  17          18
# 대문_commons.wikimedia.org_desktop_all-agents                193         184
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1134        1137
# ［Alexandros］_ja.wikipedia.org_all-access_spider             79          79
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           317         313
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         826         828
#
#                                                     2017-09-14  2017-09-15  \
# !vote_en.wikipedia.org_all-access_all-agents                10          10
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           5
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1075        1056
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          20          19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         633         603
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         607         598
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         417         398
# "Keep_me_logged_in"_extended_to_one_year_www.me...          28          27
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          18          17
# "Keep_me_logged_in"_extended_to_one_year_www.me...          10          10
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2605        2619
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          59          58
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1307        1253
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           5           5
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          47          47
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          19          17
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          28          28
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              183         163
# (236984)_Astier_fr.wikipedia.org_all-access_all...          16          16
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       8           8
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     35          35
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  29          33
# 龍應台_zh.wikipedia.org_all-access_all-agents                 371         342
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    221         196
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   5           5
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 101          98
# 龍涎香_zh.wikipedia.org_all-access_spider                       8           8
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     54          50
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 880         888
# 龍珠超_zh.wikipedia.org_all-access_spider                      27          26
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    593         593
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 289         294
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                414         380
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   260         227
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 251         244
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      17          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    112         109
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 128         124
# 龔照勝_zh.wikipedia.org_desktop_all-agents                     10           9
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                207         210
# 대문_commons.wikimedia.org_all-access_all-agents             182         171
# 대문_commons.wikimedia.org_all-access_spider                  19          19
# 대문_commons.wikimedia.org_desktop_all-agents                177         166
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1146        1167
# ［Alexandros］_ja.wikipedia.org_all-access_spider             81          83
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           314         312
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         839         865
#
#                                                     2017-09-16  2017-09-17  \
# !vote_en.wikipedia.org_all-access_all-agents                10           9
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1062        1092
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          20          20
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         571         595
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         595         611
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         370         386
# "Keep_me_logged_in"_extended_to_one_year_www.me...          27          26
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          17          17
# "Keep_me_logged_in"_extended_to_one_year_www.me...          11          11
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2663        2710
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          56          56
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1113        1101
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           5
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          45          46
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          14          15
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          29          31
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              135         150
# (236984)_Astier_fr.wikipedia.org_all-access_all...          17          19
# (236984)_Astier_fr.wikipedia.org_all-access_spider           4           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       9           9
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     36          37
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  48          49
# 龍應台_zh.wikipedia.org_all-access_all-agents                 319         360
# 龍應台_zh.wikipedia.org_all-access_spider                      16          16
# 龍應台_zh.wikipedia.org_desktop_all-agents                    161         190
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                  98         103
# 龍涎香_zh.wikipedia.org_all-access_spider                       9           9
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     44          47
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1113        1503
# 龍珠超_zh.wikipedia.org_all-access_spider                      29          33
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    722        1001
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 371         474
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                323         351
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     17          17
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   163         177
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 239         248
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    103         105
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 126         134
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      7           7
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                230         243
# 대문_commons.wikimedia.org_all-access_all-agents             150         155
# 대문_commons.wikimedia.org_all-access_spider                  20          20
# 대문_commons.wikimedia.org_desktop_all-agents                138         144
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1300        1370
# ［Alexandros］_ja.wikipedia.org_all-access_spider             95          99
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           313         325
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         999        1047
#
#                                                     2017-09-18  2017-09-19  \
# !vote_en.wikipedia.org_all-access_all-agents                10          10
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           5
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1096        1112
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          20          20
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         637         652
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         625         618
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         426         428
# "Keep_me_logged_in"_extended_to_one_year_www.me...          26          25
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          17          17
# "Keep_me_logged_in"_extended_to_one_year_www.me...          10          10
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2675        2656
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          59          60
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1317        1367
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           2
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          52          53
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          20          21
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          31          30
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              176         177
# (236984)_Astier_fr.wikipedia.org_all-access_all...          18          18
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       9           9
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     39          38
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  36          34
# 龍應台_zh.wikipedia.org_all-access_all-agents                 378         375
# 龍應台_zh.wikipedia.org_all-access_spider                      17          17
# 龍應台_zh.wikipedia.org_desktop_all-agents                    224         223
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 106         106
# 龍涎香_zh.wikipedia.org_all-access_spider                       9           9
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     56          57
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1161        1016
# 龍珠超_zh.wikipedia.org_all-access_spider                      30          29
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    819         705
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 355         318
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                434         443
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   264         274
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 251         250
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      17          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    112         110
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 129         129
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      9           9
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                219         216
# 대문_commons.wikimedia.org_all-access_all-agents             179         181
# 대문_commons.wikimedia.org_all-access_spider                  21          21
# 대문_commons.wikimedia.org_desktop_all-agents                172         174
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1232        1208
# ［Alexandros］_ja.wikipedia.org_all-access_spider             87          85
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           333         332
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         896         882
#
#                                                     2017-09-20  2017-09-21  \
# !vote_en.wikipedia.org_all-access_all-agents                10           9
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    5           5
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1103        1093
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          20          19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         648         638
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         622         614
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         431         421
# "Keep_me_logged_in"_extended_to_one_year_www.me...          25          25
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          17          17
# "Keep_me_logged_in"_extended_to_one_year_www.me...           9           9
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2658        2662
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          60          59
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1364        1346
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           2           2
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_en.wikipedia.org_all-access_all...          54          55
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          22          21
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          30          32
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              168         160
# (236984)_Astier_fr.wikipedia.org_all-access_all...          18          18
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                       9           9
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     36          35
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  32          31
# 龍應台_zh.wikipedia.org_all-access_all-agents                 381         369
# 龍應台_zh.wikipedia.org_all-access_spider                      17          17
# 龍應台_zh.wikipedia.org_desktop_all-agents                    226         217
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   6           6
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 106         104
# 龍涎香_zh.wikipedia.org_all-access_spider                       9           9
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     57          56
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 958         907
# 龍珠超_zh.wikipedia.org_all-access_spider                      29          28
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    658         617
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 304         292
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                438         429
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   274         266
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 250         247
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          17
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    110         109
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 129         127
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      9           9
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                216         214
# 대문_commons.wikimedia.org_all-access_all-agents             182         177
# 대문_commons.wikimedia.org_all-access_spider                  21          21
# 대문_commons.wikimedia.org_desktop_all-agents                174         167
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1197        1195
# ［Alexandros］_ja.wikipedia.org_all-access_spider             85          86
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           330         328
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...         877         883
#
#                                                        ...      2017-11-04  \
# !vote_en.wikipedia.org_all-access_all-agents           ...               7
# !vote_en.wikipedia.org_all-access_spider               ...               3
# !vote_en.wikipedia.org_desktop_all-agents              ...               4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...     ...            1094
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...     ...              19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...     ...             585
# "European_Society_for_Clinical_Investigation"_e...     ...               2
# "European_Society_for_Clinical_Investigation"_e...     ...               0
# "European_Society_for_Clinical_Investigation"_e...     ...               2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...     ...             622
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...     ...              13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...     ...             388
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...              22
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...               3
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...              15
# "Keep_me_logged_in"_extended_to_one_year_www.me...     ...               7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...     ...            2675
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...     ...              60
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...     ...            1061
# %s_www.mediawiki.org_mobile-web_all-agents             ...               0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...     ...              12
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...     ...               3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...     ...               7
# 'Tis_the_Season_en.wikipedia.org_all-access_all...     ...             108
# 'Tis_the_Season_en.wikipedia.org_all-access_spider     ...               6
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...     ...              35
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...     ...              67
# (1)_Ceres_de.wikipedia.org_desktop_all-agents          ...             112
# (236984)_Astier_fr.wikipedia.org_all-access_all...     ...              23
# (236984)_Astier_fr.wikipedia.org_all-access_spider     ...               4
# ...                                                    ...             ...
# 龍千玉_zh.wikipedia.org_all-access_spider                 ...              14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                ...              34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents             ...              72
# 龍應台_zh.wikipedia.org_all-access_all-agents             ...             281
# 龍應台_zh.wikipedia.org_all-access_spider                 ...              18
# 龍應台_zh.wikipedia.org_desktop_all-agents                ...             148
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents             ...               8
# 龍涎香_zh.wikipedia.org_all-access_all-agents             ...             108
# 龍涎香_zh.wikipedia.org_all-access_spider                 ...              10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                ...              51
# 龍珠超_zh.wikipedia.org_all-access_all-agents             ...            1082
# 龍珠超_zh.wikipedia.org_all-access_spider                 ...              31
# 龍珠超_zh.wikipedia.org_desktop_all-agents                ...             696
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents             ...             352
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents            ...             363
# 龐茲騙局_zh.wikipedia.org_all-access_spider                ...              18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents               ...             171
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents             ...             247
# 龔嘉欣_zh.wikipedia.org_all-access_spider                 ...              16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                ...              97
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents             ...             142
# 龔照勝_zh.wikipedia.org_desktop_all-agents                ...               7
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents            ...             284
# 대문_commons.wikimedia.org_all-access_all-agents         ...             152
# 대문_commons.wikimedia.org_all-access_spider             ...              24
# 대문_commons.wikimedia.org_desktop_all-agents            ...             135
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...     ...            1667
# ［Alexandros］_ja.wikipedia.org_all-access_spider        ...             122
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents       ...             366
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...     ...            1290
#
#                                                     2017-11-05  2017-11-06  \
# !vote_en.wikipedia.org_all-access_all-agents                 6           6
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    3           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1120        1137
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          18          19
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         605         644
# "European_Society_for_Clinical_Investigation"_e...           1           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           1           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         632         631
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          14
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         402         432
# "Keep_me_logged_in"_extended_to_one_year_www.me...          22          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2755        2701
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          59          61
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1076        1293
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          12          13
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           7           6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         104         120
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          36          55
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          68          67
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              126         154
# (236984)_Astier_fr.wikipedia.org_all-access_all...          24          24
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     34          34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  78          53
# 龍應台_zh.wikipedia.org_all-access_all-agents                 301         316
# 龍應台_zh.wikipedia.org_all-access_spider                      18          18
# 龍應台_zh.wikipedia.org_desktop_all-agents                    163         189
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   8           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 104         108
# 龍涎香_zh.wikipedia.org_all-access_spider                      10          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     48          58
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1353        1072
# 龍珠超_zh.wikipedia.org_all-access_spider                      33          32
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    889         740
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 421         327
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                388         453
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     17          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   184         262
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 258         253
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    101         107
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 149         135
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      7           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                301         262
# 대문_commons.wikimedia.org_all-access_all-agents             154         174
# 대문_commons.wikimedia.org_all-access_spider                  24          24
# 대문_commons.wikimedia.org_desktop_all-agents                138         161
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1691        1509
# ［Alexandros］_ja.wikipedia.org_all-access_spider            123         107
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           375         378
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1286        1093
#
#                                                     2017-11-07  2017-11-08  \
# !vote_en.wikipedia.org_all-access_all-agents                 7           7
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1149        1138
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          18          18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         655         651
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           1
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         627         628
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         436         436
# "Keep_me_logged_in"_extended_to_one_year_www.me...          22          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2603        2582
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          61          62
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1305        1293
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          13          13
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         136         141
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           6           6
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          69          73
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          68          69
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              153         149
# (236984)_Astier_fr.wikipedia.org_all-access_all...          23          23
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     33          33
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  47          47
# 龍應台_zh.wikipedia.org_all-access_all-agents                 315         315
# 龍應台_zh.wikipedia.org_all-access_spider                      18          18
# 龍應台_zh.wikipedia.org_desktop_all-agents                    190         188
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 110         108
# 龍涎香_zh.wikipedia.org_all-access_spider                      10          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     59          59
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 953         920
# 龍珠超_zh.wikipedia.org_all-access_spider                      30          30
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    646         617
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 301         292
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                458         460
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   269         273
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 249         245
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    105         103
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 133         132
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                251         251
# 대문_commons.wikimedia.org_all-access_all-agents             179         179
# 대문_commons.wikimedia.org_all-access_spider                  24          24
# 대문_commons.wikimedia.org_desktop_all-agents                167         166
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1454        1438
# ［Alexandros］_ja.wikipedia.org_all-access_spider            105         103
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           375         370
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1062        1058
#
#                                                     2017-11-09  2017-11-10  \
# !vote_en.wikipedia.org_all-access_all-agents                 7           6
# !vote_en.wikipedia.org_all-access_spider                     2           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1128        1108
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          18          18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         644         622
# "European_Society_for_Clinical_Investigation"_e...           2           2
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           1           1
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         603         602
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         409         402
# "Keep_me_logged_in"_extended_to_one_year_www.me...          22          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2524        2593
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          62          61
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1253        1208
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          12          12
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           6           6
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         128         127
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          66          60
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          62          65
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              144         134
# (236984)_Astier_fr.wikipedia.org_all-access_all...          23          23
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          14
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     32          32
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  47          52
# 龍應台_zh.wikipedia.org_all-access_all-agents                 309         296
# 龍應台_zh.wikipedia.org_all-access_spider                      18          18
# 龍應台_zh.wikipedia.org_desktop_all-agents                    183         170
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7           7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 107         105
# 龍涎香_zh.wikipedia.org_all-access_spider                      10          10
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     58          55
# 龍珠超_zh.wikipedia.org_all-access_all-agents                 885         887
# 龍珠超_zh.wikipedia.org_all-access_spider                      29          29
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    590         587
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 283         285
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                444         407
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   258         230
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 241         235
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    101          98
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 130         128
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8           8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                248         253
# 대문_commons.wikimedia.org_all-access_all-agents             174         163
# 대문_commons.wikimedia.org_all-access_spider                  24          24
# 대문_commons.wikimedia.org_desktop_all-agents                160         150
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1435        1483
# ［Alexandros］_ja.wikipedia.org_all-access_spider            103         105
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           367         365
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1059        1110
#
#                                                     2017-11-11  2017-11-12  \
# !vote_en.wikipedia.org_all-access_all-agents                 7           6
# !vote_en.wikipedia.org_all-access_spider                     3           2
# !vote_en.wikipedia.org_desktop_all-agents                    4           3
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1106        1127
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          19          18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         592         609
# "European_Society_for_Clinical_Investigation"_e...           2           1
# "European_Society_for_Clinical_Investigation"_e...           0           0
# "European_Society_for_Clinical_Investigation"_e...           2           1
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         605         627
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          14          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         370         391
# "Keep_me_logged_in"_extended_to_one_year_www.me...          21          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2702        2762
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          61          59
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1056        1076
# %s_www.mediawiki.org_mobile-web_all-agents                   0           0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          13          13
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           8           8
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         118         124
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           6           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          42          42
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          71          79
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              114         129
# (236984)_Astier_fr.wikipedia.org_all-access_all...          24          26
# (236984)_Astier_fr.wikipedia.org_all-access_spider           4           3
# ...                                                        ...         ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      14          15
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     33          35
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  79          83
# 龍應台_zh.wikipedia.org_all-access_all-agents                 285         302
# 龍應台_zh.wikipedia.org_all-access_spider                      18          18
# 龍應台_zh.wikipedia.org_desktop_all-agents                    149         161
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7           8
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 104         108
# 龍涎香_zh.wikipedia.org_all-access_spider                      11          11
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     48          52
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1081        1326
# 龍珠超_zh.wikipedia.org_all-access_spider                      32          33
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    697         874
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 351         416
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                358         387
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     18          18
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   173         190
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 241         250
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16          16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                     94          97
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 139         146
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      7           7
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                289         309
# 대문_commons.wikimedia.org_all-access_all-agents             149         153
# 대문_commons.wikimedia.org_all-access_spider                  24          24
# 대문_commons.wikimedia.org_desktop_all-agents                131         136
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1660        1748
# ［Alexandros］_ja.wikipedia.org_all-access_spider            119         124
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           367         381
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1287        1341
#
#                                                     2017-11-13
# !vote_en.wikipedia.org_all-access_all-agents                 6
# !vote_en.wikipedia.org_all-access_spider                     2
# !vote_en.wikipedia.org_desktop_all-agents                    4
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...        1146
# "Awaken,_My_Love!"_en.wikipedia.org_all-access_...          18
# "Awaken,_My_Love!"_en.wikipedia.org_desktop_all...         648
# "European_Society_for_Clinical_Investigation"_e...           2
# "European_Society_for_Clinical_Investigation"_e...           0
# "European_Society_for_Clinical_Investigation"_e...           2
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...         632
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_a...          13
# "Heroes"_(David_Bowie_album)_en.wikipedia.org_d...         426
# "Keep_me_logged_in"_extended_to_one_year_www.me...          22
# "Keep_me_logged_in"_extended_to_one_year_www.me...           3
# "Keep_me_logged_in"_extended_to_one_year_www.me...          15
# "Keep_me_logged_in"_extended_to_one_year_www.me...           7
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...        2630
# "Weird_Al"_Yankovic_en.wikipedia.org_all-access...          62
# "Weird_Al"_Yankovic_en.wikipedia.org_desktop_al...        1260
# %s_www.mediawiki.org_mobile-web_all-agents                   0
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...          14
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           3
# 'Tis_the_Season_(Vince_Gill_and_Olivia_Newton-J...           7
# 'Tis_the_Season_en.wikipedia.org_all-access_all...         152
# 'Tis_the_Season_en.wikipedia.org_all-access_spider           5
# 'Tis_the_Season_en.wikipedia.org_desktop_all-ag...          69
# 'Tis_the_Season_en.wikipedia.org_mobile-web_all...          81
# (1)_Ceres_de.wikipedia.org_desktop_all-agents              154
# (236984)_Astier_fr.wikipedia.org_all-access_all...          25
# (236984)_Astier_fr.wikipedia.org_all-access_spider           3
# ...                                                        ...
# 龍千玉_zh.wikipedia.org_all-access_spider                      15
# 龍千玉_zh.wikipedia.org_desktop_all-agents                     34
# 龍千玉_zh.wikipedia.org_mobile-web_all-agents                  53
# 龍應台_zh.wikipedia.org_all-access_all-agents                 310
# 龍應台_zh.wikipedia.org_all-access_spider                      19
# 龍應台_zh.wikipedia.org_desktop_all-agents                    184
# 龍抬頭_zh.wikipedia.org_mobile-web_all-agents                   7
# 龍涎香_zh.wikipedia.org_all-access_all-agents                 111
# 龍涎香_zh.wikipedia.org_all-access_spider                      11
# 龍涎香_zh.wikipedia.org_desktop_all-agents                     61
# 龍珠超_zh.wikipedia.org_all-access_all-agents                1062
# 龍珠超_zh.wikipedia.org_all-access_spider                      32
# 龍珠超_zh.wikipedia.org_desktop_all-agents                    731
# 龍珠超_zh.wikipedia.org_mobile-web_all-agents                 327
# 龐茲騙局_zh.wikipedia.org_all-access_all-agents                445
# 龐茲騙局_zh.wikipedia.org_all-access_spider                     19
# 龐茲騙局_zh.wikipedia.org_desktop_all-agents                   266
# 龔嘉欣_zh.wikipedia.org_all-access_all-agents                 248
# 龔嘉欣_zh.wikipedia.org_all-access_spider                      16
# 龔嘉欣_zh.wikipedia.org_desktop_all-agents                    103
# 龔嘉欣_zh.wikipedia.org_mobile-web_all-agents                 134
# 龔照勝_zh.wikipedia.org_desktop_all-agents                      8
# 龙生九子_zh.wikipedia.org_mobile-web_all-agents                268
# 대문_commons.wikimedia.org_all-access_all-agents             173
# 대문_commons.wikimedia.org_all-access_spider                  25
# 대문_commons.wikimedia.org_desktop_all-agents                160
# ［Alexandros］_ja.wikipedia.org_all-access_all-ag...        1541
# ［Alexandros］_ja.wikipedia.org_all-access_spider            108
# ［Alexandros］_ja.wikipedia.org_desktop_all-agents           382
# ［Alexandros］_ja.wikipedia.org_mobile-web_all-ag...        1125
#
# [145063 rows x 63 columns]

# %%
prev.loc[missing_pages, '2016-12-15':]
# Out:
#                                                     2016-12-15  2016-12-16  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         1.0         NaN
# Category:Deletion_requests_January_2016_commons...         0.0         NaN
# Category:Deletion_requests_January_2016_commons...         1.0         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-17  2016-12-18  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         0.0
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         0.0         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-19  2016-12-20  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         0.0
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         0.0         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         1.0
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             0.0         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-21  2016-12-22  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         0.0         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2016-12-23  2016-12-24  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         0.0         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         4.0         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         0.0
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                        ...      2017-09-02  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...     ...             NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...     ...             NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...     ...             NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...     ...             NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider       ...             NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents      ...             NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...     ...             NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...     ...             NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...     ...             NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...     ...             NaN
# Artificial_Insemination's_Art_www.mediawiki.org...     ...             NaN
# Artificial_Insemination's_Art_www.mediawiki.org...     ...             NaN
# Category:Deletion_requests_April_2016_commons.w...     ...             NaN
# Category:Deletion_requests_April_2016_commons.w...     ...             NaN
# Category:Deletion_requests_April_2016_commons.w...     ...             NaN
# Category:Deletion_requests_February_2016_common...     ...             NaN
# Category:Deletion_requests_February_2016_common...     ...             NaN
# Category:Deletion_requests_February_2016_common...     ...             NaN
# Category:Deletion_requests_January_2016_commons...     ...             NaN
# Category:Deletion_requests_January_2016_commons...     ...             NaN
# Category:Deletion_requests_January_2016_commons...     ...             NaN
# Category:Deletion_requests_July_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_June_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_June_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_June_2016_commons.wi...     ...             NaN
# Category:Deletion_requests_March_2016_commons.w...     ...             NaN
# Category:Deletion_requests_May_2016_commons.wik...     ...             NaN
# Category:Deletion_requests_May_2016_commons.wik...     ...             NaN
# Category:Deletion_requests_May_2016_commons.wik...     ...             NaN
# Category:Deletion_requests_October_2016_commons...     ...             NaN
# ...                                                    ...             ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...     ...             NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...     ...             NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...     ...             NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents             ...             NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                 ...             NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                ...             NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents             ...             NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents         ...             NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider            ...             NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents        ...             0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents             ...             NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                 ...             NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents             ...             NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents         ...             NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents           ...             NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider               ...             NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents              ...             NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents             ...             NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                 ...             NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                ...             NaN
#
#                                                     2017-09-03  2017-09-04  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-05  2017-09-06  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         2.0         1.0
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         0.0
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         0.0
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         0.0
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-07  2017-09-08  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         0.0
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         0.0         0.0
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             0.0         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            0.0         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 0.0         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             0.0         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-09  2017-09-10  \
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_February_2016_common...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_January_2016_commons...         NaN         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN         NaN
# Category:Deletion_requests_October_2016_commons...         NaN         NaN
# ...                                                        ...         ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN         NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN         NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN         NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN         NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN         NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN         NaN
#
#                                                     2017-09-11
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN
# 100_лучших_героев_комиксов_по_версии_IGN_ru.wik...         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_all-a...         NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_all-access_spider           NaN
# 2015年華潔洗滌罷工事件_zh.wikipedia.org_desktop_all-agents          NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_all-...         NaN
# ????:Andrey_Belloly_1.jpg_ru.wikipedia.org_desk...         NaN
# Akash_Thosar_en.wikipedia.org_mobile-web_all-ag...         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN
# Artificial_Insemination's_Art_www.mediawiki.org...         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN
# Category:Deletion_requests_April_2016_commons.w...         NaN
# Category:Deletion_requests_February_2016_common...         NaN
# Category:Deletion_requests_February_2016_common...         NaN
# Category:Deletion_requests_February_2016_common...         NaN
# Category:Deletion_requests_January_2016_commons...         NaN
# Category:Deletion_requests_January_2016_commons...         NaN
# Category:Deletion_requests_January_2016_commons...         NaN
# Category:Deletion_requests_July_2016_commons.wi...         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN
# Category:Deletion_requests_June_2016_commons.wi...         NaN
# Category:Deletion_requests_March_2016_commons.w...         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN
# Category:Deletion_requests_May_2016_commons.wik...         NaN
# Category:Deletion_requests_October_2016_commons...         NaN
# ...                                                        ...
# 特別:フィード項目/featured/20160905000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160906000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160912000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160914000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160916000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160918000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160920000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160922000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160925000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160926000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20160927000000/ja_ja.wikiped...         NaN
# 特別:フィード項目/featured/20161003000000/ja_ja.wikiped...         NaN
# 特別:リンク元/ファイル:WikiThanks.png_ja.wikipedia.org_mo...         NaN
# 王軼玲_zh.wikipedia.org_all-access_all-agents                 NaN
# 王軼玲_zh.wikipedia.org_all-access_spider                     NaN
# 王軼玲_zh.wikipedia.org_desktop_all-agents                    NaN
# 王軼玲_zh.wikipedia.org_mobile-web_all-agents                 NaN
# 袁弘_(演员)_zh.wikipedia.org_mobile-web_all-agents             NaN
# 金雪炫_(歌手)_zh.wikipedia.org_all-access_spider                NaN
# 金雪炫_(歌手)_zh.wikipedia.org_mobile-web_all-agents            NaN
# 陳明憲_zh.wikipedia.org_all-access_all-agents                 NaN
# 陳明憲_zh.wikipedia.org_all-access_spider                     NaN
# 陳明憲_zh.wikipedia.org_mobile-web_all-agents                 NaN
# 陳煒_(藝人)_zh.wikipedia.org_mobile-web_all-agents             NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_all-agents               NaN
# 馬惜珍家族_zh.wikipedia.org_all-access_spider                   NaN
# 馬惜珍家族_zh.wikipedia.org_desktop_all-agents                  NaN
# 马澄坤_zh.wikipedia.org_all-access_all-agents                 NaN
# 马澄坤_zh.wikipedia.org_all-access_spider                     NaN
# 马澄坤_zh.wikipedia.org_desktop_all-agents                    NaN
#
# [798 rows x 271 columns]
